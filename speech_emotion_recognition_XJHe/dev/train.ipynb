# %%
"""

@author: daehyeon
"""

from __future__ import division, print_function, absolute_import

# %%
import numpy as np
import tensorflow as tf
from acrnn1 import acrnn
from extract_mel import next_batch, test_dataset
import cPickle
import matplotlib.pyplot as plt

from sklearn.metrics import precision_score as precision
from sklearn.metrics import recall_score as recall
from sklearn.metrics import confusion_matrix as confusion
import os

# %%
tf.app.flags.DEFINE_integer('num_epoch', 30000, 'The number of epoches for training.')
tf.app.flags.DEFINE_integer('num_classes', 7, 'The number of emotion classes.')
tf.app.flags.DEFINE_integer('batch_size', 45, 'The number of samples in each batch.')
tf.app.flags.DEFINE_boolean('is_adam', True, 'whether to use adam optimizer.')
tf.app.flags.DEFINE_float('learning_rate', 0.00001, 'learning rate of Adam optimizer')
tf.app.flags.DEFINE_float('dropout_keep_prob', 1, 'the prob of every unit keep in dropout layer')
tf.app.flags.DEFINE_integer('image_height', 300, 'image height')
tf.app.flags.DEFINE_integer('image_width', 40, 'image width')
tf.app.flags.DEFINE_integer('image_channel', 3, 'image channels as input')
tf.app.flags.DEFINE_integer('val_iter', 5, 'the number of validation test')

tf.app.flags.DEFINE_string('checkpoint', './checkpoint/', 'the checkpoint dir')
tf.app.flags.DEFINE_string('model_name', 'model4.ckpt', 'model name')
tf.app.flags.DEFINE_string('f', '', 'kernel')

FLAGS = tf.app.flags.FLAGS

# %%
history_acc = []
history_cost = []

def train():
    best_valid_uw = 0
    best_valid_ac = 0
    
    X = tf.placeholder(tf.float32, shape=[None, FLAGS.image_height,FLAGS.image_width,FLAGS.image_channel])
    Y = tf.placeholder(tf.int32, shape=[None, FLAGS.num_classes])
    
    is_training = tf.placeholder(tf.bool)
    lr = tf.placeholder(tf.float32) # learning rate
    
    keep_prob = tf.placeholder(tf.float32) # drop out rate
    
    Ylogits = acrnn(X, is_training=is_training, dropout_keep_prob=keep_prob) # result
    
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels =  Y, logits =  Ylogits)

    cost = tf.reduce_mean(cross_entropy)
    var_trainable_op = tf.trainable_variables()
    if FLAGS.is_adam:
        # not apply gradient clipping
        train_op = tf.train.AdamOptimizer(lr).minimize(cost)            
    else:
        # apply gradient clipping
        grads, _ = tf.clip_by_global_norm(tf.gradients(cost, var_trainable_op), 5)
        opti = tf.train.AdamOptimizer(lr)
        train_op = opti.apply_gradients(zip(grads, var_trainable_op))
    
    correct_pred = tf.equal(tf.argmax(Ylogits, 1), tf.argmax(Y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    saver=tf.train.Saver(tf.global_variables())
    init = tf.global_variables_initializer()
    
    with tf.Session() as sess:
        sess.run(init)
        for i in range(FLAGS.num_epoch):
            data, label, _ = next_batch(FLAGS.batch_size, train=True)
            
            #train
            [_,tcost,tracc] = sess.run([train_op,cost,accuracy], feed_dict={X:data, Y:label,
                                            is_training:True, keep_prob:FLAGS.dropout_keep_prob, lr:FLAGS.learning_rate})
            
            # ploting. check and stop when it overfits.
            if(i%300 == 0):
                plt.plot(range(0,len(history_acc)), history_acc)
                plt.savefig("./checkpoint/acc.png")
                plt.plot(range(0,len(history_cost)), history_cost)
                plt.savefig("./checkpoint/cost.png")
                
            #validation
            if( i% 5 == 0):
                whole_y_valid = []
                whole_y_pred = []
                
                cost_valid = 0
                valid_data_size = 0
                for v in range(FLAGS.val_iter):
                    valid_data, valid_label, pernums_valid = next_batch(FLAGS.batch_size, train=False)
                    valid_data_size += valid_label.shape[0]
                    loss, y_pred_valid = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data, Y:valid_label,is_training:False, keep_prob:1})
                    
                    index = 0
                    y_valid_list = []
                    valid_label_list = []
                    for s in range(pernums_valid.shape[0]):
                        y_valid = np.max(y_pred_valid[index : index+ pernums_valid[s]], 0)
                        
                        y_valid_list.append(y_valid)
                        valid_label_list.append(valid_label[index+pernums_valid[s]-1])
                        
                        index = index+ pernums_valid[s]
                    
                    cost_valid += np.sum(loss) # cost sum of validation
                    
                    whole_y_valid += valid_label_list
                    whole_y_pred += y_valid_list
                    
                cost_valid = cost_valid/valid_data_size
                
                valid_acc = np.equal(np.argmax(whole_y_valid,1),np.argmax(whole_y_pred,1))
                valid_acc = np.mean(valid_acc)
                
                history_acc.append(valid_acc)
                history_cost.append(cost_valid)
                
                valid_conf = confusion(np.argmax(whole_y_valid, 1),np.argmax(whole_y_pred,1))
                
                if valid_acc > best_valid_ac:
                    best_valid_ac = valid_acc
                    best_valid_conf = valid_conf
                    saver.save(sess, os.path.join(FLAGS.checkpoint, FLAGS.model_name), global_step = i+1)
                
                print ("*****************************************************************")
                print ("Epoch: %05d" %(i+1))
                print ("Training cost: %2.3g" %tcost)   
                print ("Training accuracy: %3.4g" %tracc) 
                print ("Valid acc: %3.4g" %valid_acc)
                print ("Best valid acc: %3.4g" %best_valid_ac)
                print ("")
                print ("Valid cost: %2.3g" %cost_valid)
                #print ('Valid Confusion Matrix:["ang","sad","hap","neu"]')
                #print (valid_conf)
                #print ('Best Valid Confusion Matrix:["ang","sad","hap","neu"]')
                #print (best_valid_conf)
                print ("*****************************************************************" )

# %%
train()
# Out:
# WARNING:tensorflow:From <ipython-input-4-4fcfda1340e0>:18: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# *****************************************************************
# Epoch: 00001
# Training cost: 2.06
# Training accuracy: 0.1237
# Valid acc: 0.1022
# Best valid acc: 0.1022
#
# Valid cost:  2
# *****************************************************************
# *****************************************************************
# Epoch: 00006
# Training cost: 1.94
# Training accuracy: 0.1296
# Valid acc: 0.1244
# Best valid acc: 0.1244
#
# Valid cost: 1.96
# *****************************************************************
# *****************************************************************
# Epoch: 00011
# Training cost: 1.96
# Training accuracy: 0.1509
# Valid acc: 0.16
# Best valid acc: 0.16
#
# Valid cost: 1.94
# *****************************************************************
# *****************************************************************
# Epoch: 00016
# Training cost: 1.92
# Training accuracy: 0.175
# Valid acc: 0.1733
# Best valid acc: 0.1733
#
# Valid cost: 1.94
# *****************************************************************
# *****************************************************************
# Epoch: 00021
# Training cost: 1.96
# Training accuracy: 0.1524
# Valid acc: 0.2178
# Best valid acc: 0.2178
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00026
# Training cost: 1.89
# Training accuracy: 0.2476
# Valid acc: 0.1956
# Best valid acc: 0.2178
#
# Valid cost: 1.95
# *****************************************************************
# *****************************************************************
# Epoch: 00031
# Training cost: 1.94
# Training accuracy: 0.2294
# Valid acc: 0.2222
# Best valid acc: 0.2222
#
# Valid cost: 1.93
# *****************************************************************
# *****************************************************************
# Epoch: 00036
# Training cost: 1.87
# Training accuracy: 0.2336
# Valid acc: 0.2444
# Best valid acc: 0.2444
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00041
# Training cost: 1.85
# Training accuracy: 0.2605
# Valid acc: 0.2044
# Best valid acc: 0.2444
#
# Valid cost: 1.93
# *****************************************************************
# *****************************************************************
# Epoch: 00046
# Training cost: 1.99
# Training accuracy: 0.08411
# Valid acc: 0.2089
# Best valid acc: 0.2444
#
# Valid cost: 1.94
# *****************************************************************
# *****************************************************************
# Epoch: 00051
# Training cost: 1.97
# Training accuracy: 0.1583
# Valid acc: 0.1911
# Best valid acc: 0.2444
#
# Valid cost: 1.96
# *****************************************************************
# *****************************************************************
# Epoch: 00056
# Training cost: 1.95
# Training accuracy: 0.1604
# Valid acc: 0.2667
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00061
# Training cost: 1.88
# Training accuracy: 0.2793
# Valid acc: 0.2533
# Best valid acc: 0.2667
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00066
# Training cost: 1.9
# Training accuracy: 0.2913
# Valid acc: 0.2311
# Best valid acc: 0.2667
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00071
# Training cost: 1.86
# Training accuracy: 0.3514
# Valid acc: 0.1911
# Best valid acc: 0.2667
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00076
# Training cost: 1.86
# Training accuracy: 0.243
# Valid acc: 0.2267
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00081
# Training cost: 1.87
# Training accuracy: 0.303
# Valid acc: 0.2267
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00086
# Training cost: 1.91
# Training accuracy: 0.2075
# Valid acc: 0.2222
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00091
# Training cost: 1.95
# Training accuracy: 0.1613
# Valid acc: 0.2
# Best valid acc: 0.2667
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00096
# Training cost: 1.89
# Training accuracy: 0.1681
# Valid acc: 0.2222
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00101
# Training cost: 1.96
# Training accuracy: 0.1887
# Valid acc: 0.2089
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00106
# Training cost: 1.96
# Training accuracy: 0.1351
# Valid acc: 0.1911
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00111
# Training cost: 1.88
# Training accuracy: 0.2407
# Valid acc: 0.2178
# Best valid acc: 0.2667
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00116
# Training cost: 1.94
# Training accuracy: 0.1182
# Valid acc: 0.1867
# Best valid acc: 0.2667
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00121
# Training cost: 1.92
# Training accuracy: 0.1078
# Valid acc: 0.2178
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00126
# Training cost: 1.88
# Training accuracy: 0.2321
# Valid acc: 0.2222
# Best valid acc: 0.2667
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00131
# Training cost: 1.84
# Training accuracy: 0.2389
# Valid acc: 0.2444
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00136
# Training cost: 1.89
# Training accuracy: 0.3333
# Valid acc: 0.2089
# Best valid acc: 0.2667
#
# Valid cost: 1.95
# *****************************************************************
# *****************************************************************
# Epoch: 00141
# Training cost: 1.89
# Training accuracy: 0.2451
# Valid acc: 0.2578
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00146
# Training cost: 1.89
# Training accuracy: 0.215
# Valid acc: 0.2311
# Best valid acc: 0.2667
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00151
# Training cost: 1.9
# Training accuracy: 0.1923
# Valid acc: 0.2356
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00156
# Training cost: 1.92
# Training accuracy: 0.2342
# Valid acc: 0.2533
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00161
# Training cost: 1.93
# Training accuracy: 0.1616
# Valid acc: 0.2667
# Best valid acc: 0.2667
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00166
# Training cost: 1.87
# Training accuracy: 0.2736
# Valid acc: 0.2356
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00171
# Training cost: 1.91
# Training accuracy: 0.2056
# Valid acc: 0.1956
# Best valid acc: 0.2667
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00176
# Training cost: 1.85
# Training accuracy: 0.2925
# Valid acc: 0.2711
# Best valid acc: 0.2711
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00181
# Training cost: 1.9
# Training accuracy: 0.2
# Valid acc: 0.2489
# Best valid acc: 0.2711
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00186
# Training cost: 1.84
# Training accuracy: 0.2353
# Valid acc: 0.2267
# Best valid acc: 0.2711
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00191
# Training cost: 1.89
# Training accuracy: 0.1683
# Valid acc: 0.2133
# Best valid acc: 0.2711
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00196
# Training cost: 1.81
# Training accuracy: 0.2906
# Valid acc: 0.2044
# Best valid acc: 0.2711
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00201
# Training cost: 1.85
# Training accuracy: 0.2991
# Valid acc: 0.2756
# Best valid acc: 0.2756
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00206
# Training cost: 1.91
# Training accuracy: 0.2095
# Valid acc: 0.2489
# Best valid acc: 0.2756
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00211
# Training cost: 1.92
# Training accuracy: 0.1782
# Valid acc: 0.1822
# Best valid acc: 0.2756
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00216
# Training cost: 1.86
# Training accuracy: 0.2571
# Valid acc: 0.2489
# Best valid acc: 0.2756
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00221
# Training cost: 1.9
# Training accuracy: 0.2222
# Valid acc: 0.24
# Best valid acc: 0.2756
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00226
# Training cost: 1.81
# Training accuracy: 0.303
# Valid acc: 0.2178
# Best valid acc: 0.2756
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00231
# Training cost: 1.84
# Training accuracy: 0.313
# Valid acc: 0.2356
# Best valid acc: 0.2756
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00236
# Training cost: 1.91
# Training accuracy: 0.1652
# Valid acc: 0.2444
# Best valid acc: 0.2756
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00241
# Training cost: 1.79
# Training accuracy: 0.2832
# Valid acc: 0.2533
# Best valid acc: 0.2756
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00246
# Training cost: 1.94
# Training accuracy: 0.16
# Valid acc: 0.2578
# Best valid acc: 0.2756
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00251
# Training cost: 1.94
# Training accuracy: 0.134
# Valid acc: 0.2844
# Best valid acc: 0.2844
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00256
# Training cost: 1.9
# Training accuracy: 0.2358
# Valid acc: 0.2756
# Best valid acc: 0.2844
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00261
# Training cost: 1.88
# Training accuracy: 0.2037
# Valid acc: 0.2356
# Best valid acc: 0.2844
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00266
# Training cost: 1.83
# Training accuracy: 0.3269
# Valid acc: 0.2444
# Best valid acc: 0.2844
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00271
# Training cost: 1.92
# Training accuracy: 0.1727
# Valid acc: 0.24
# Best valid acc: 0.2844
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00276
# Training cost: 1.88
# Training accuracy: 0.25
# Valid acc: 0.2622
# Best valid acc: 0.2844
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00281
# Training cost: 1.89
# Training accuracy: 0.2
# Valid acc: 0.24
# Best valid acc: 0.2844
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00286
# Training cost: 1.93
# Training accuracy: 0.1981
# Valid acc: 0.2933
# Best valid acc: 0.2933
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00291
# Training cost: 1.84
# Training accuracy: 0.181
# Valid acc: 0.3156
# Best valid acc: 0.3156
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00296
# Training cost: 1.9
# Training accuracy: 0.1698
# Valid acc: 0.2622
# Best valid acc: 0.3156
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00301
# Training cost: 1.83
# Training accuracy: 0.2982
# Valid acc: 0.2356
# Best valid acc: 0.3156
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00306
# Training cost: 1.88
# Training accuracy: 0.2269
# Valid acc: 0.1822
# Best valid acc: 0.3156
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00311
# Training cost: 1.83
# Training accuracy: 0.2478
# Valid acc: 0.2089
# Best valid acc: 0.3156
#
# Valid cost: 1.93
# *****************************************************************
# *****************************************************************
# Epoch: 00316
# Training cost: 1.91
# Training accuracy: 0.2243
# Valid acc: 0.3067
# Best valid acc: 0.3156
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00321
# Training cost: 1.81
# Training accuracy: 0.3039
# Valid acc: 0.32
# Best valid acc: 0.32
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00326
# Training cost: 1.9
# Training accuracy: 0.2286
# Valid acc: 0.2844
# Best valid acc: 0.32
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00331
# Training cost: 1.87
# Training accuracy: 0.1714
# Valid acc: 0.2756
# Best valid acc: 0.32
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00336
# Training cost: 1.87
# Training accuracy: 0.2381
# Valid acc: 0.2356
# Best valid acc: 0.32
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00341
# Training cost: 1.91
# Training accuracy: 0.1754
# Valid acc: 0.2489
# Best valid acc: 0.32
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00346
# Training cost: 1.84
# Training accuracy: 0.2358
# Valid acc: 0.2622
# Best valid acc: 0.32
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00351
# Training cost: 1.86
# Training accuracy: 0.243
# Valid acc: 0.2489
# Best valid acc: 0.32
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00356
# Training cost: 1.85
# Training accuracy: 0.2477
# Valid acc: 0.2
# Best valid acc: 0.32
#
# Valid cost: 1.93
# *****************************************************************
# *****************************************************************
# Epoch: 00361
# Training cost: 1.93
# Training accuracy: 0.2059
# Valid acc: 0.2222
# Best valid acc: 0.32
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00366
# Training cost: 1.89
# Training accuracy: 0.1964
# Valid acc: 0.2711
# Best valid acc: 0.32
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00371
# Training cost: 1.9
# Training accuracy: 0.1826
# Valid acc: 0.2578
# Best valid acc: 0.32
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00376
# Training cost: 1.83
# Training accuracy: 0.2455
# Valid acc: 0.28
# Best valid acc: 0.32
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00381
# Training cost: 1.89
# Training accuracy: 0.2364
# Valid acc: 0.2578
# Best valid acc: 0.32
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00386
# Training cost: 1.84
# Training accuracy: 0.2617
# Valid acc: 0.2489
# Best valid acc: 0.32
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00391
# Training cost: 1.87
# Training accuracy: 0.2475
# Valid acc: 0.2356
# Best valid acc: 0.32
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00396
# Training cost: 1.82
# Training accuracy: 0.2233
# Valid acc: 0.2889
# Best valid acc: 0.32
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00401
# Training cost: 1.88
# Training accuracy: 0.2407
# Valid acc: 0.2667
# Best valid acc: 0.32
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00406
# Training cost: 1.87
# Training accuracy: 0.1961
# Valid acc: 0.2978
# Best valid acc: 0.32
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00411
# Training cost: 1.9
# Training accuracy: 0.2427
# Valid acc: 0.28
# Best valid acc: 0.32
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00416
# Training cost: 1.8
# Training accuracy: 0.2925
# Valid acc: 0.2578
# Best valid acc: 0.32
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00421
# Training cost: 1.87
# Training accuracy: 0.202
# Valid acc: 0.2
# Best valid acc: 0.32
#
# Valid cost: 1.92
# *****************************************************************
# *****************************************************************
# Epoch: 00426
# Training cost: 1.81
# Training accuracy: 0.3551
# Valid acc: 0.2933
# Best valid acc: 0.32
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00431
# Training cost:  2
# Training accuracy: 0.1481
# Valid acc: 0.2133
# Best valid acc: 0.32
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00436
# Training cost: 1.88
# Training accuracy: 0.2571
# Valid acc: 0.2444
# Best valid acc: 0.32
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00441
# Training cost: 1.94
# Training accuracy: 0.1226
# Valid acc: 0.2044
# Best valid acc: 0.32
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00446
# Training cost: 1.85
# Training accuracy: 0.2593
# Valid acc: 0.2267
# Best valid acc: 0.32
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00451
# Training cost: 1.91
# Training accuracy: 0.1518
# Valid acc: 0.2444
# Best valid acc: 0.32
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00456
# Training cost: 1.87
# Training accuracy: 0.2323
# Valid acc: 0.3022
# Best valid acc: 0.32
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00461
# Training cost: 1.86
# Training accuracy: 0.2475
# Valid acc: 0.36
# Best valid acc: 0.36
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00466
# Training cost: 1.86
# Training accuracy: 0.2143
# Valid acc: 0.2933
# Best valid acc: 0.36
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00471
# Training cost: 1.73
# Training accuracy: 0.3491
# Valid acc: 0.3022
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00476
# Training cost: 1.93
# Training accuracy: 0.2261
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00481
# Training cost: 1.85
# Training accuracy: 0.2385
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00486
# Training cost: 1.88
# Training accuracy: 0.2321
# Valid acc: 0.2667
# Best valid acc: 0.36
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00491
# Training cost: 1.78
# Training accuracy: 0.268
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00496
# Training cost: 1.84
# Training accuracy: 0.25
# Valid acc: 0.2622
# Best valid acc: 0.36
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00501
# Training cost: 1.84
# Training accuracy: 0.2569
# Valid acc: 0.2844
# Best valid acc: 0.36
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00506
# Training cost: 1.86
# Training accuracy: 0.2762
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00511
# Training cost: 1.79
# Training accuracy: 0.2963
# Valid acc: 0.2578
# Best valid acc: 0.36
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00516
# Training cost: 1.85
# Training accuracy: 0.283
# Valid acc: 0.28
# Best valid acc: 0.36
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00521
# Training cost: 1.85
# Training accuracy: 0.2605
# Valid acc: 0.2489
# Best valid acc: 0.36
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00526
# Training cost: 1.88
# Training accuracy: 0.22
# Valid acc: 0.2756
# Best valid acc: 0.36
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00531
# Training cost: 1.88
# Training accuracy: 0.2545
# Valid acc: 0.3067
# Best valid acc: 0.36
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00536
# Training cost: 1.82
# Training accuracy: 0.2523
# Valid acc: 0.2667
# Best valid acc: 0.36
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00541
# Training cost: 1.84
# Training accuracy: 0.2692
# Valid acc: 0.3422
# Best valid acc: 0.36
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00546
# Training cost: 1.88
# Training accuracy: 0.2115
# Valid acc: 0.2444
# Best valid acc: 0.36
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00551
# Training cost: 1.85
# Training accuracy: 0.2523
# Valid acc: 0.2844
# Best valid acc: 0.36
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00556
# Training cost: 1.83
# Training accuracy: 0.2689
# Valid acc: 0.3067
# Best valid acc: 0.36
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00561
# Training cost: 1.78
# Training accuracy: 0.3063
# Valid acc: 0.2889
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00566
# Training cost: 1.88
# Training accuracy: 0.1538
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 00571
# Training cost: 1.92
# Training accuracy: 0.26
# Valid acc: 0.2311
# Best valid acc: 0.36
#
# Valid cost: 1.93
# *****************************************************************
# *****************************************************************
# Epoch: 00576
# Training cost: 1.85
# Training accuracy: 0.2593
# Valid acc: 0.2756
# Best valid acc: 0.36
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00581
# Training cost: 1.81
# Training accuracy: 0.31
# Valid acc: 0.3067
# Best valid acc: 0.36
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00586
# Training cost: 1.83
# Training accuracy: 0.3273
# Valid acc: 0.2756
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00591
# Training cost: 1.85
# Training accuracy: 0.233
# Valid acc: 0.3333
# Best valid acc: 0.36
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00596
# Training cost: 1.78
# Training accuracy: 0.2642
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00601
# Training cost: 1.87
# Training accuracy: 0.2636
# Valid acc: 0.3289
# Best valid acc: 0.36
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00606
# Training cost: 1.83
# Training accuracy: 0.2885
# Valid acc: 0.3111
# Best valid acc: 0.36
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00611
# Training cost: 1.9
# Training accuracy: 0.2095
# Valid acc: 0.2356
# Best valid acc: 0.36
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00616
# Training cost: 1.76
# Training accuracy: 0.2883
# Valid acc: 0.2489
# Best valid acc: 0.36
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00621
# Training cost: 1.91
# Training accuracy: 0.2212
# Valid acc: 0.2756
# Best valid acc: 0.36
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00626
# Training cost: 1.91
# Training accuracy: 0.1296
# Valid acc: 0.3778
# Best valid acc: 0.3778
#
# Valid cost: 1.8
# *****************************************************************
# *****************************************************************
# Epoch: 00631
# Training cost: 1.87
# Training accuracy: 0.2203
# Valid acc: 0.32
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00636
# Training cost: 1.9
# Training accuracy: 0.3304
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00641
# Training cost: 1.78
# Training accuracy: 0.3238
# Valid acc: 0.3378
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00646
# Training cost: 1.85
# Training accuracy: 0.2982
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00651
# Training cost: 1.89
# Training accuracy: 0.1743
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00656
# Training cost: 1.87
# Training accuracy: 0.2569
# Valid acc: 0.3244
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00661
# Training cost: 1.81
# Training accuracy: 0.2736
# Valid acc: 0.2622
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00666
# Training cost: 1.88
# Training accuracy: 0.22
# Valid acc: 0.3156
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00671
# Training cost: 1.87
# Training accuracy: 0.1887
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00676
# Training cost: 1.82
# Training accuracy: 0.2569
# Valid acc: 0.32
# Best valid acc: 0.3778
#
# Valid cost: 1.82
# *****************************************************************
# *****************************************************************
# Epoch: 00681
# Training cost: 1.82
# Training accuracy: 0.2323
# Valid acc: 0.2889
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00686
# Training cost: 1.79
# Training accuracy: 0.2703
# Valid acc: 0.3511
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00691
# Training cost: 1.81
# Training accuracy: 0.287
# Valid acc: 0.2533
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00696
# Training cost: 1.85
# Training accuracy: 0.2897
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00701
# Training cost: 1.75
# Training accuracy: 0.3271
# Valid acc: 0.2533
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00706
# Training cost: 1.78
# Training accuracy: 0.2621
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00711
# Training cost: 1.75
# Training accuracy: 0.2273
# Valid acc: 0.24
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00716
# Training cost: 1.87
# Training accuracy: 0.2397
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00721
# Training cost: 1.86
# Training accuracy: 0.2524
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00726
# Training cost: 1.88
# Training accuracy: 0.2636
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00731
# Training cost: 1.85
# Training accuracy: 0.2589
# Valid acc: 0.2578
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00736
# Training cost: 1.95
# Training accuracy: 0.2252
# Valid acc: 0.3111
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00741
# Training cost: 1.84
# Training accuracy: 0.2295
# Valid acc: 0.2578
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00746
# Training cost: 1.77
# Training accuracy: 0.2755
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00751
# Training cost: 1.85
# Training accuracy: 0.2571
# Valid acc: 0.2889
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00756
# Training cost: 1.79
# Training accuracy: 0.3061
# Valid acc: 0.3644
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00761
# Training cost: 1.78
# Training accuracy: 0.3137
# Valid acc: 0.2889
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00766
# Training cost: 1.73
# Training accuracy: 0.3364
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00771
# Training cost: 1.86
# Training accuracy: 0.2617
# Valid acc: 0.2667
# Best valid acc: 0.3778
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00776
# Training cost: 1.79
# Training accuracy: 0.2476
# Valid acc: 0.2489
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00781
# Training cost: 1.77
# Training accuracy: 0.3431
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00786
# Training cost: 1.83
# Training accuracy: 0.233
# Valid acc: 0.2444
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00791
# Training cost: 1.83
# Training accuracy: 0.2762
# Valid acc: 0.2444
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00796
# Training cost: 1.81
# Training accuracy: 0.2885
# Valid acc: 0.32
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00801
# Training cost: 1.84
# Training accuracy: 0.2991
# Valid acc: 0.2889
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00806
# Training cost: 1.81
# Training accuracy: 0.2936
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00811
# Training cost: 1.83
# Training accuracy: 0.2
# Valid acc: 0.3378
# Best valid acc: 0.3778
#
# Valid cost: 1.8
# *****************************************************************
# *****************************************************************
# Epoch: 00816
# Training cost: 1.79
# Training accuracy: 0.2793
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00821
# Training cost: 1.86
# Training accuracy: 0.2178
# Valid acc: 0.3778
# Best valid acc: 0.3778
#
# Valid cost: 1.8
# *****************************************************************
# *****************************************************************
# Epoch: 00826
# Training cost: 1.75
# Training accuracy: 0.3186
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00831
# Training cost: 1.83
# Training accuracy: 0.2772
# Valid acc: 0.28
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00836
# Training cost: 1.76
# Training accuracy: 0.3925
# Valid acc: 0.3556
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00841
# Training cost: 1.84
# Training accuracy: 0.2385
# Valid acc: 0.2889
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00846
# Training cost: 1.83
# Training accuracy: 0.2432
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00851
# Training cost: 1.78
# Training accuracy: 0.3036
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.82
# *****************************************************************
# *****************************************************************
# Epoch: 00856
# Training cost: 1.81
# Training accuracy: 0.3153
# Valid acc: 0.3156
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00861
# Training cost: 1.79
# Training accuracy: 0.2571
# Valid acc: 0.2622
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00866
# Training cost: 1.85
# Training accuracy: 0.2056
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00871
# Training cost: 1.85
# Training accuracy: 0.2857
# Valid acc: 0.2578
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00876
# Training cost: 1.78
# Training accuracy: 0.36
# Valid acc: 0.2622
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00881
# Training cost: 1.81
# Training accuracy: 0.271
# Valid acc: 0.2711
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00886
# Training cost: 1.83
# Training accuracy: 0.2456
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00891
# Training cost: 1.75
# Training accuracy: 0.2957
# Valid acc: 0.2578
# Best valid acc: 0.3778
#
# Valid cost: 1.88
# *****************************************************************
# *****************************************************************
# Epoch: 00896
# Training cost: 1.78
# Training accuracy: 0.3009
# Valid acc: 0.2489
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00901
# Training cost: 1.85
# Training accuracy: 0.2193
# Valid acc: 0.3289
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00906
# Training cost: 1.79
# Training accuracy: 0.1923
# Valid acc: 0.3511
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00911
# Training cost: 1.83
# Training accuracy: 0.2157
# Valid acc: 0.3556
# Best valid acc: 0.3778
#
# Valid cost: 1.8
# *****************************************************************
# *****************************************************************
# Epoch: 00916
# Training cost: 1.67
# Training accuracy: 0.3818
# Valid acc: 0.2578
# Best valid acc: 0.3778
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 00921
# Training cost: 1.85
# Training accuracy: 0.2056
# Valid acc: 0.3556
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00926
# Training cost: 1.95
# Training accuracy: 0.1649
# Valid acc: 0.2622
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 00931
# Training cost: 1.82
# Training accuracy: 0.2455
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00936
# Training cost: 1.82
# Training accuracy: 0.2039
# Valid acc: 0.3378
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00941
# Training cost: 1.87
# Training accuracy: 0.2
# Valid acc: 0.3156
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 00946
# Training cost: 1.75
# Training accuracy: 0.2844
# Valid acc: 0.32
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00951
# Training cost: 1.8
# Training accuracy: 0.297
# Valid acc: 0.2667
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00956
# Training cost: 1.8
# Training accuracy: 0.29
# Valid acc: 0.3378
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00961
# Training cost: 1.94
# Training accuracy: 0.2222
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 00966
# Training cost: 1.85
# Training accuracy: 0.2328
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00971
# Training cost: 1.78
# Training accuracy: 0.3455
# Valid acc: 0.3467
# Best valid acc: 0.3778
#
# Valid cost: 1.82
# *****************************************************************
# *****************************************************************
# Epoch: 00976
# Training cost: 1.74
# Training accuracy: 0.2981
# Valid acc: 0.2667
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 00981
# Training cost: 1.85
# Training accuracy: 0.2818
# Valid acc: 0.2667
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 00986
# Training cost: 1.77
# Training accuracy: 0.2883
# Valid acc: 0.3111
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 00991
# Training cost: 1.76
# Training accuracy: 0.2832
# Valid acc: 0.36
# Best valid acc: 0.3778
#
# Valid cost: 1.8
# *****************************************************************
# *****************************************************************
# Epoch: 00996
# Training cost: 1.84
# Training accuracy: 0.2411
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.82
# *****************************************************************
# *****************************************************************
# Epoch: 01001
# Training cost: 1.82
# Training accuracy: 0.1909
# Valid acc: 0.2711
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 01006
# Training cost: 1.81
# Training accuracy: 0.2667
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 01011
# Training cost: 1.81
# Training accuracy: 0.3097
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 01016
# Training cost: 1.87
# Training accuracy: 0.2321
# Valid acc: 0.3111
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 01021
# Training cost: 1.84
# Training accuracy: 0.2389
# Valid acc: 0.2978
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 01026
# Training cost: 1.79
# Training accuracy: 0.3302
# Valid acc: 0.2756
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 01031
# Training cost: 1.89
# Training accuracy: 0.1495
# Valid acc: 0.28
# Best valid acc: 0.3778
#
# Valid cost: 1.87
# *****************************************************************
# *****************************************************************
# Epoch: 01036
# Training cost: 1.72
# Training accuracy: 0.4091
# Valid acc: 0.2667
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 01041
# Training cost: 1.81
# Training accuracy: 0.2719
# Valid acc: 0.2444
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 01046
# Training cost: 1.88
# Training accuracy: 0.301
# Valid acc: 0.3022
# Best valid acc: 0.3778
#
# Valid cost: 1.81
# *****************************************************************
# *****************************************************************
# Epoch: 01051
# Training cost: 1.8
# Training accuracy: 0.1909
# Valid acc: 0.3289
# Best valid acc: 0.3778
#
# Valid cost: 1.82
# *****************************************************************
# *****************************************************************
# Epoch: 01056
# Training cost: 1.86
# Training accuracy: 0.25
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
# *****************************************************************
# Epoch: 01061
# Training cost: 1.84
# Training accuracy: 0.2946
# Valid acc: 0.2533
# Best valid acc: 0.3778
#
# Valid cost: 1.91
# *****************************************************************
# *****************************************************************
# Epoch: 01066
# Training cost: 1.74
# Training accuracy: 0.2952
# Valid acc: 0.3333
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 01071
# Training cost: 1.72
# Training accuracy: 0.2807
# Valid acc: 0.2844
# Best valid acc: 0.3778
#
# Valid cost: 1.85
# *****************************************************************
# *****************************************************************
# Epoch: 01076
# Training cost: 1.8
# Training accuracy: 0.2952
# Valid acc: 0.3378
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 01081
# Training cost: 1.86
# Training accuracy: 0.2243
# Valid acc: 0.3111
# Best valid acc: 0.3778
#
# Valid cost: 1.83
# *****************************************************************
# *****************************************************************
# Epoch: 01086
# Training cost: 1.77
# Training accuracy: 0.3043
# Valid acc: 0.2622
# Best valid acc: 0.3778
#
# Valid cost: 1.89
# *****************************************************************
# *****************************************************************
# Epoch: 01091
# Training cost: 1.82
# Training accuracy: 0.2477
# Valid acc: 0.3067
# Best valid acc: 0.3778
#
# Valid cost: 1.84
# *****************************************************************
# *****************************************************************
# Epoch: 01096
# Training cost: 1.82
# Training accuracy: 0.2752
# Valid acc: 0.2711
# Best valid acc: 0.3778
#
# Valid cost: 1.9
# *****************************************************************
# *****************************************************************
# Epoch: 01101
# Training cost: 1.8
# Training accuracy: 0.2589
# Valid acc: 0.2933
# Best valid acc: 0.3778
#
# Valid cost: 1.86
# *****************************************************************
